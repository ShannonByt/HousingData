# %% [markdown]
# ## Exercise

# %% [markdown]
# For this exercise, you will be working with the [House Price Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code).
#
# Please grab the train.csv file from Kaggle and explore this dataset. You need to perform explroatory data analysis and see if there is any correlation between the variables and analyze the distribution of the dataset. The question is open-ended and basically you're asked to perform EDA.

# %% [markdown]
# 1- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 3 of your assignment, you need to submit at least one jupyter notebook file and one pdf file.
#
#
# 2- Push your code and project to github and provide the link to your code here. Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Making new dataframes to make it cleaner as there are 80 columns in the original dataset.
df=pd.read_csv('train.csv')
newdf=df[['LotArea','Neighborhood','SalePrice','OverallQual','OverallCond','SaleCondition']]
newdf# This df deals with neighborhood,housestyle,year sold etc, price.
dfdf=df[['SalePrice','OverallQual']]

# %%
#quickly looking at the numerical variables 
newdf.describe()
# Out:
#              LotArea      SalePrice  OverallQual  OverallCond
# count    1460.000000    1460.000000  1460.000000  1460.000000
# mean    10516.828082  180921.195890     6.099315     5.575342
# std      9981.264932   79442.502883     1.382997     1.112799
# min      1300.000000   34900.000000     1.000000     1.000000
# 25%      7553.500000  129975.000000     5.000000     5.000000
# 50%      9478.500000  163000.000000     6.000000     5.000000
# 75%     11601.500000  214000.000000     7.000000     6.000000
# max    215245.000000  755000.000000    10.000000     9.000000

# %%
#Hypotheses and Correlational data

# %%
#Correlation analysis for the numeric data.
#Shows LotArea and saleprice Corr is 0.26. Overallqual and OverallCondition -0.09. Lastly Saleprice and OverallQual 0.79.
newdf.corr()
# Out:
#               LotArea  SalePrice  OverallQual  OverallCond
# LotArea      1.000000   0.263843     0.105806    -0.005636
# SalePrice    0.263843   1.000000     0.790982    -0.077856
# OverallQual  0.105806   0.790982     1.000000    -0.091932
# OverallCond -0.005636  -0.077856    -0.091932     1.000000

# %%
dfdf.plot(x='SalePrice',y='OverallQual',kind='scatter',title='Saleprice vs Overall Quality',marker='o',linestyle='--')
# Out:
# <AxesSubplot:title={'center':'Saleprice vs Overall Quality'}, xlabel='SalePrice', ylabel='OverallQual'>

# %%
newdf.plot(x='SalePrice',y='LotArea',kind='scatter',title='Saleprice vs Lot Area',marker='o',linestyle='--')
# Out:
# <AxesSubplot:title={'center':'Saleprice vs Lot Area'}, xlabel='SalePrice', ylabel='LotArea'>

# %%
newdf.plot(x='OverallQual',y='OverallCond',kind='scatter',title='Overall Condition vs Overall Quality')
# Out:
# <AxesSubplot:title={'center':'Overall Condition vs Overall Quality'}, xlabel='OverallQual', ylabel='OverallCond'>

# %%
dfdf.corr() #.79 correlation which is very high and shows significance.
# Out:
#              SalePrice  OverallQual
# SalePrice     1.000000     0.790982
# OverallQual   0.790982     1.000000

# %%
for i in newdf.columns:
    plt.hist(newdf[i])
    plt.title(i)
    plt.show()
